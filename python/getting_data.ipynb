# %%
# !pip install pybaseball
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------------------------------------ --- 3.7/4.0 MB 18.1 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 16.0 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/26.2 MB ? eta -:--:--
#    ----- ---------------------------------- 3.7/26.2 MB 19.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 7.9/26.2 MB 18.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 11.8/26.2 MB 18.9 MB/s eta 0:00:01
#    --------------------- ------------------ 14.4/26.2 MB 17.8 MB/s eta 0:00:01
#    -------------------------- ------------- 17.3/26.2 MB 16.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 19.7/26.2 MB 15.7 MB/s eta 0:00:01
#    --------------------------------- ------ 22.0/26.2 MB 15.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 23.3/26.2 MB 13.8 MB/s eta 0:00:01
# ...

# %%
import pybaseball

# %%
from pybaseball import  playerid_lookup
from pybaseball import  statcast_pitcher

# %%
playerid_lookup('hernández', 'félix', True)
 # name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  mlb_played_first  mlb_played_last
#0   kershaw    clayton     477132  kersc001  kershcl01           2036            2008.0           2022.0
# Out:
#    name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0  hernández      félix     433587  hernf002  hernafe02           4772
#
#    mlb_played_first  mlb_played_last
# 0            2005.0           2019.0

# %%
felix_key = 433587
stats = statcast_pitcher('2015-03-01','2016-10-31',felix_key)
# Out:
# Gathering Player Data

# %%
stats.groupby('pitch_type').release_speed.agg('mean')
# Out:
# pitch_type
# CH    88.037862
# CU    80.280261
# FF    91.734548
# PO    86.450000
# SI    91.432421
# SL    84.976855
# Name: release_speed, dtype: float64
